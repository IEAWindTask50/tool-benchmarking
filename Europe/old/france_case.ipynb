# %%
import time
import numpy as np
import pandas as pd
import os

from hydesign.assembly.hpp_assembly import hpp_model
from hydesign.examples import examples_filepath

# %%
sites = pd.read_csv('overview.csv', index_col=0)
example = 0

ex_site = sites.iloc[int(example),:]

print('Selected example site:')
print('---------------------------------------------------')
print(ex_site.T)

longitude = ex_site['longitude']
latitude = ex_site['latitude']
altitude = ex_site['altitude']
input_ts_fn = os.path.join(os.getcwd(), ex_site['input_ts_fn'])
sim_pars_fn = os.path.join(os.getcwd(), ex_site['sim_pars_fn'])

hpp = hpp_model(
        latitude,
        longitude,
        altitude,
        num_batteries = 10,
        work_dir = './',
        sim_pars_fn = sim_pars_fn,
        input_ts_fn = input_ts_fn,
        save_battry_rf_filename='battery_rf.csv',
)

inputs = dict(
clearance =	60,
sp =	287.6391934,
p_rated =	10,
Nwt	=	25,
wind_MW_per_km2 =	4.782274215,
solar_MW =	223.2191223,
surface_tilt =	50,
surface_azimuth = 210,
DC_AC_ratio	=1.295598428,
b_P =75.27402422,
b_E_h=	4.451612903,
cost_of_battery_P_fluct_in_peak_price_ratio	=0.580645161,)
# Out:
# Selected example site:
# ---------------------------------------------------
# case                                              Europe
# name                                    France_good_wind
# longitude                                      -0.864258
# latitude                                       48.744116
# altitude                                             302
# input_ts_fn      hyd_input/input_ts_France_good_wind.csv
# sim_pars_fn                       hyd_input/hpp_pars.yml
# price_fn                     hyd_input/2030-EL_PRICE.csv
# price_col                                           FR_R
# H2_demand_col                    hyd_input/H2_demand.csv
# Name: 0, dtype: object
#
# Fixed parameters on the site
# -------------------------------
# longitude = -0.864258
# latitude = 48.744116
# altitude = 302
#
# input_ts_fn length is not a complete number of years (hyDesign handles years as 365 days).
# The file has been modified and stored in ./input_ts_modified.csv

# %%
start = time.time()
outs = hpp.evaluate(**inputs)
hpp.print_design([v for k,v in inputs.items()], outs)
end = time.time()
print('exec. time [min]:', (end - start)/60 )
print(hpp.prob['NPV_over_CAPEX'])
# Out:
# Design:
# ---------------
# clearance [m]: 60.000
# sp [W/m2]: 287.639
# p_rated [MW]: 10.000
# Nwt: 25.000
# wind_MW_per_km2 [MW/km2]: 4.782
# solar_MW [MW]: 223.219
# surface_tilt [deg]: 50.000
# surface_azimuth [deg]: 210.000
# DC_AC_ratio: 1.296
# b_P [MW]: 75.274
# b_E_h [h]: 4.452
# cost_of_battery_P_fluct_in_peak_price_ratio: 0.581
#
#
# NPV_over_CAPEX: 0.134
# NPV [MEuro]: 57.417
# IRR: 0.072
# LCOE [Euro/MWh]: 33.631
# Revenues [MEuro]: 48.108
# CAPEX [MEuro]: 429.684
# OPEX [MEuro]: 6.900
# Wind CAPEX [MEuro]: 275.586
# Wind OPEX [MEuro]: 5.599
# PV CAPEX [MEuro]: 65.197
# PV OPEX [MEuro]: 1.301
# Batt CAPEX [MEuro]: 22.236
# Batt OPEX [MEuro]: 0.000
# Shared CAPEX [MEuro]: 66.665
# Shared Opex [MEuro]: 0.000
# penalty lifetime [MEuro]: 0.000
# AEP [GWh]: 1204.470
# GUF: 0.458
# grid [MW]: 300.000
# wind [MW]: 250.000
# solar [MW]: 223.219
# Battery Energy [MWh]: 335.091
# Battery Power [MW]: 75.274
# Total curtailment [GWh]: 124.724
# Awpp [km2]: 52.276
# Apvp [km2]: 2.737
# Plant area [km2]: 52.276
# Rotor diam [m]: 210.393
# Hub height [m]: 165.196
# Number of batteries used in lifetime: 2.000
# Break-even PPA price [Euro/MWh]: 35.921
# Capacity factor wind [-]: 0.414
#
# exec. time [min]: 0.14919254779815674
# [0.13362612]

# %%
from hopp.simulation import HoppInterface

# %%
hi = HoppInterface(os.path.join(os.getcwd(), "hopp_input/08-wind-solar-france.yaml"))
# Out:
# FLORIS is the system model...

# %%
hi.system.wind._financial_model.FinancialParameters.real_discount_rate = 6
hi.system.pv._financial_model.FinancialParameters.real_discount_rate = 6
hi.system.battery._financial_model.FinancialParameters.real_discount_rate = 6
hi.system.grid._financial_model.FinancialParameters.real_discount_rate = 6

hi.system.wind._financial_model.FinancialParameters.inflation_rate = 2
hi.system.pv._financial_model.FinancialParameters.inflation_rate = 2
hi.system.battery._financial_model.FinancialParameters.inflation_rate = 2
hi.system.grid._financial_model.FinancialParameters.inflation_rate = 2

# Federal tax rate 21%, set state tax rate to 4% (total 25% tax rate)
hi.system.wind._financial_model.FinancialParameters.state_tax_rate = [4]*25
hi.system.pv._financial_model.FinancialParameters.state_tax_rate = [4]*25
hi.system.battery._financial_model.FinancialParameters.state_tax_rate = [4]*25
hi.system.grid._financial_model.FinancialParameters.state_tax_rate = [4]*25

# %%
hi.simulate(25)
# Out:
# Simulating wind farm output in FLORIS...

# %%
hybrid_plant = hi.system

annual_energies = hybrid_plant.annual_energies
npvs = hybrid_plant.net_present_values
cf = hybrid_plant.capacity_factors

wind_installed_cost = hybrid_plant.wind.total_installed_cost
solar_installed_cost = hybrid_plant.pv.total_installed_cost
battery_installed_cost = hybrid_plant.battery.total_installed_cost
hybrid_installed_cost = hybrid_plant.grid.total_installed_cost

print("Wind Installed Cost [M$]: {}".format(wind_installed_cost/1e6))
print("Solar Installed Cost [M$]: {}".format(solar_installed_cost/1e6))
print("Battery Installed Cost [M$]: {}".format(battery_installed_cost/1e6))
print("Hybrid Installed Cost [M$]: {}\n".format(hybrid_installed_cost/1e6))

print("Wind NPV [M$]: {}".format(hybrid_plant.net_present_values.wind/1e6))
print("Solar NPV [M$]: {}".format(hybrid_plant.net_present_values.pv/1e6))
print("Hybrid NPV [M$]: {}\n".format(hybrid_plant.net_present_values.hybrid/1e6))

print("Annual Energies [kW]",annual_energies)
print("Capacity Factors",cf)
print("NPV [$]", npvs)

print("LCOE [cents/kWh]", hybrid_plant.lcoe_real,"\n")

print("Hybrid LCOE [$/MWh]", hybrid_plant.lcoe_real['hybrid']*10)
# Out:
# Wind Installed Cost [M$]: 241.227
# Solar Installed Cost [M$]: 54.989034800000006
# Battery Installed Cost [M$]: 17.5693665
# Hybrid Installed Cost [M$]: 313.7854013
#
# Wind NPV [M$]: 63.246082237556756
# Solar NPV [M$]: 7.465036194840506
# Hybrid NPV [M$]: 66.04674247862494
#
# Annual Energies [kW] {"pv": 277789162.6264313, "wind": 663116990.2109435, "battery": -2974975.4070675476, "hybrid": 936708992.6552676}
# Capacity Factors {"pv": 18.486286596963403, "wind": 30.279314621504266, "battery": 0, "hybrid": 21.563237776446694}
# NPV [$] {"pv": 7465036.194840506, "wind": 63246082.237556756, "battery": -641223.1976308338, "hybrid": 66046742.47862494}
# LCOE [cents/kWh] {"pv": 2.4562456386505964, "wind": 2.9136197604315184, "battery": 5.087488923794693, "hybrid": 3.052223127291031}
#
# Hybrid LCOE [$/MWh] 30.52223127291031

# %%
import json

with open("singleowner.json", 'w') as f:
    dat = hybrid_plant.grid._financial_model.export()
    d = dict()
    for k, v in dat.items():
        d.update(v)
    json.dump(d, f)

# %%
euro_per_dollar = 1.0
df = pd.DataFrame({'HOPP': [wind_installed_cost/1e6*euro_per_dollar,
                            solar_installed_cost/1e6*euro_per_dollar,
                            battery_installed_cost/1e6*euro_per_dollar,
                            hybrid_installed_cost/1e6*euro_per_dollar,
                            hybrid_plant.net_present_values.hybrid/1e6*euro_per_dollar,
                           ],
                   'HyDesign': [float(hpp.prob['wpp_cost.CAPEX_w']/1e6),
                                float(hpp.prob['pvp_cost.CAPEX_s']/1e6),
                                float(hpp.prob['battery_cost.CAPEX_b']/1e6),
                                float(hpp.prob['CAPEX']/1e6),
                                float(hpp.prob['NPV']/1e6),
                                ] },
                  index=['CAPEX Wind [M€]',
                         'CAPEX Solar [M€]',
                         'CAPEX Battery [M€]',
                         'CAPEX Hybrid [M€]',
                         'NPV Hybrid [M€]',
                        ])
# Out:
# /var/folders/xr/5t2dyj2s43l49g5t42x7nd9dq0q89q/T/ipykernel_52444/3229776475.py:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   'HyDesign': [float(hpp.prob['wpp_cost.CAPEX_w']/1e6),
# /var/folders/xr/5t2dyj2s43l49g5t42x7nd9dq0q89q/T/ipykernel_52444/3229776475.py:9: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   float(hpp.prob['pvp_cost.CAPEX_s']/1e6),
# /var/folders/xr/5t2dyj2s43l49g5t42x7nd9dq0q89q/T/ipykernel_52444/3229776475.py:10: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   float(hpp.prob['battery_cost.CAPEX_b']/1e6),
# /var/folders/xr/5t2dyj2s43l49g5t42x7nd9dq0q89q/T/ipykernel_52444/3229776475.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   float(hpp.prob['CAPEX']/1e6),
# /var/folders/xr/5t2dyj2s43l49g5t42x7nd9dq0q89q/T/ipykernel_52444/3229776475.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   float(hpp.prob['NPV']/1e6),

# %%
df
# Out:
#                           HOPP    HyDesign
# CAPEX Wind [M€]     241.227000  275.586490
# CAPEX Solar [M€]     54.989035   65.196875
# CAPEX Battery [M€]   17.569367   22.235916
# CAPEX Hybrid [M€]   313.785401  429.684196
# NPV Hybrid [M€]      66.046742   57.417031

# %%
hpp.prob.model.list_outputs()
# Out:
# 45 Explicit Output(s) in 'model'
#
# varname                               val                   prom_name
# ------------------------------------  --------------------  --------------------------------------------
# abl
#   wst                                 |817.46032848|        abl.wst
# genericWT
#   ws                                  |117.70938833|        genericWT.ws
#   pc                                  |5.71613057|          genericWT.pc
#   ct                                  |3.31364971|          genericWT.ct
# genericWake
#   pcw                                 |1413.01276995|       genericWake.pcw
# wpp
#   wind_t                              |12206.75107181|      wpp.wind_t
# pvp
#   solar_t                             |6226.64451123|       pvp.solar_t
#   Apvp                                [2.73666644]          pvp.Apvp
# ems
#   wind_t_ext                          |61033.75535903|      ems.wind_t_ext
#   solar_t_ext                         |31133.22255613|      ems.solar_t_ext
#   price_t_ext                         |21354.67102979|      ems.price_t_ext
#   hpp_t                               |75604.76567371|      ems.hpp_t
#   hpp_curt_t                          |1462.01943911|       ems.hpp_curt_t
#   b_t                                 |17655.49542738|      ems.b_t
#   b_E_SOC_t                           |90587.57209633|      ems.b_E_SOC_t
#   penalty_t                           |0.0|                 ems.penalty_t
# battery_degradation
#   SoH                                 |397.22575514|        battery_degradation.SoH
#   n_batteries                         [2.]                  battery_degradation.n_batteries
# battery_loss_in_capacity_due_to_temp
#   SoH_all                             |382.92619526|        battery_loss_in_capacity_due_to_temp.SoH_all
# wpp_with_degradation
#   wind_t_ext_deg                      |61033.75535903|      wpp_with_degradation.wind_t_ext_deg
# pvp_with_degradation
#   solar_t_ext_deg                     |31133.22255613|      pvp_with_degradation.solar_t_ext_deg
# ems_long_term_operation
#   hpp_t_with_deg                      |75561.47715873|      ems_long_term_operation.hpp_t_with_deg
#   hpp_curt_t_with_deg                 |2342.45578407|       ems_long_term_operation.hpp_curt_t_with_deg
#   b_t_with_deg                        |16040.5391312|       ems_long_term_operation.b_t_with_deg
#   b_E_SOC_t_with_deg                  |75072.88310529|      ems_long_term_operation.b_E_SOC_t_with_deg
#   penalty_t_with_deg                  |0.0|                 ems_long_term_operation.penalty_t_with_deg
#   total_curtailment                   [124724.33562569]     total_curtailment
# wpp_cost
#   CAPEX_w                             [2.7558649e+08]       wpp_cost.CAPEX_w
#   OPEX_w                              [5598766.78143823]    wpp_cost.OPEX_w
# pvp_cost
#   CAPEX_s                             [65196874.67579814]   pvp_cost.CAPEX_s
#   OPEX_s                              [1301410.54778139]    pvp_cost.OPEX_s
# battery_cost
#   CAPEX_b                             [22235916.21067887]   battery_cost.CAPEX_b
#   OPEX_b                              [0.]                  battery_cost.OPEX_b
# shared_cost
#   CAPEX_sh                            [66664914.99570566]   shared_cost.CAPEX_sh
#   OPEX_sh                             [0.]                  shared_cost.OPEX_sh
# finance
#   CAPEX                               [4.29684196e+08]      CAPEX
#   OPEX                                [6900177.32921962]    OPEX
#   NPV                                 [57417031.07367174]   NPV
#   IRR                                 [0.07246433]          IRR
#   NPV_over_CAPEX                      [0.13362612]          NPV_over_CAPEX
#   mean_AEP                            [1204469.80277355]    mean_AEP
#   LCOE                                [33.6307702]          LCOE
#   revenues                            [48108452.04615024]   revenues
#   penalty_lifetime                    [0.]                  penalty_lifetime
#   break_even_PPA_price                [35.92120164]         break_even_PPA_price
#
#
# 0 Implicit Output(s) in 'model'
# [('abl.wst',
#   {'val': array([12.5730722 , 11.58387731, 11.8185967 , ..., 12.50101548,
#           13.00332079, 13.29007885]),
#    'prom_name': 'abl.wst'}),
#  ('battery_cost.CAPEX_b',
#   {'val': array([22235916.21067887]), 'prom_name': 'battery_cost.CAPEX_b'}),
#  ('battery_cost.OPEX_b',
#   {'val': array([0.]), 'prom_name': 'battery_cost.OPEX_b'}),
#  ('battery_degradation.SoH',
#   {'val': array([0.99995228, 0.9999375 , 0.99992271, ..., 0.7163223 , 0.71631931,
#           0.71631931]),
#    'prom_name': 'battery_degradation.SoH'}),
#  ('battery_degradation.n_batteries',
#   {'val': array([2.]), 'prom_name': 'battery_degradation.n_batteries'}),
#  ('battery_loss_in_capacity_due_to_temp.SoH_all',
#   {'val': array([0.97811107, 0.97733277, 0.97680722, ..., 0.68082447, 0.68048509,
#           0.68039783]),
#    'prom_name': 'battery_loss_in_capacity_due_to_temp.SoH_all'}),
#  ('ems.wind_t_ext',
#   {'val': array([216.63691369, 211.60142827, 213.3433593 , ..., 216.51662194,
#           217.35208738, 217.56441215]),
#    'prom_name': 'ems.wind_t_ext'}),
#  ('ems.solar_t_ext',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]),
#    'prom_name': 'ems.solar_t_ext'}),
#  ('ems.price_t_ext',
#   {'val': array([32.685, 32.685, 32.685, ..., 35.362, 34.468, 33.417]),
#    'prom_name': 'ems.price_t_ext'}),
#  ('ems.hpp_t',
#   {'val': array([188.14279656, 183.10731113, 184.84924217, ..., 216.51662194,
#           187.61909559, 187.83142035]),
#    'prom_name': 'ems.hpp_t'}),
#  ('ems.hpp_curt_t',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]),
#    'prom_name': 'ems.hpp_curt_t'}),
#  ('ems.b_t',
#   {'val': array([-28.49411713, -28.49411713, -28.49411713, ...,   0.        ,
#           -29.7329918 , -29.7329918 ]),
#    'prom_name': 'ems.b_t'}),
#  ('ems.b_E_SOC_t',
#   {'val': array([167.54540874, 195.46964353, 223.39387832, ..., 109.26874482,
#           138.40707678, 167.54540874]),
#    'prom_name': 'ems.b_E_SOC_t'}),
#  ('ems.penalty_t',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]), 'prom_name': 'ems.penalty_t'}),
#  ('ems_long_term_operation.hpp_t_with_deg',
#   {'val': array([188.14279656, 183.10731113, 184.84924217, ..., 216.51662194,
#           187.61909559, 187.83142035]),
#    'prom_name': 'ems_long_term_operation.hpp_t_with_deg'}),
#  ('ems_long_term_operation.hpp_curt_t_with_deg',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]),
#    'prom_name': 'ems_long_term_operation.hpp_curt_t_with_deg'}),
#  ('ems_long_term_operation.b_t_with_deg',
#   {'val': array([-28.49411713, -28.49411713, -28.49411713, ...,   0.        ,
#           -29.7329918 , -29.7329918 ]),
#    'prom_name': 'ems_long_term_operation.b_t_with_deg'}),
#  ('ems_long_term_operation.b_E_SOC_t_with_deg',
#   {'val': array([167.54540874, 195.46964353, 223.39387832, ...,  22.89222238,
#            52.03055434,  81.1688863 ]),
#    'prom_name': 'ems_long_term_operation.b_E_SOC_t_with_deg'}),
#  ('ems_long_term_operation.penalty_t_with_deg',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]),
#    'prom_name': 'ems_long_term_operation.penalty_t_with_deg'}),
#  ('ems_long_term_operation.total_curtailment',
#   {'val': array([124724.33562569]), 'prom_name': 'total_curtailment'}),
#  ('finance.CAPEX', {'val': array([4.29684196e+08]), 'prom_name': 'CAPEX'}),
#  ('finance.OPEX', {'val': array([6900177.32921962]), 'prom_name': 'OPEX'}),
#  ('finance.NPV', {'val': array([57417031.07367174]), 'prom_name': 'NPV'}),
#  ('finance.IRR', {'val': array([0.07246433]), 'prom_name': 'IRR'}),
#  ('finance.NPV_over_CAPEX',
#   {'val': array([0.13362612]), 'prom_name': 'NPV_over_CAPEX'}),
#  ('finance.mean_AEP',
#   {'val': array([1204469.80277355]), 'prom_name': 'mean_AEP'}),
#  ('finance.LCOE', {'val': array([33.6307702]), 'prom_name': 'LCOE'}),
#  ('finance.revenues',
#   {'val': array([48108452.04615024]), 'prom_name': 'revenues'}),
#  ('finance.penalty_lifetime',
#   {'val': array([0.]), 'prom_name': 'penalty_lifetime'}),
#  ('finance.break_even_PPA_price',
#   {'val': array([35.92120164]), 'prom_name': 'break_even_PPA_price'}),
#  ('genericWT.ws',
#   {'val': array([ 0.  ,  1.5 ,  2.  ,  2.5 ,  3.  ,  3.5 ,  4.  ,  4.5 ,  5.  ,
#            5.5 ,  6.  ,  6.5 ,  7.  ,  7.5 ,  8.  ,  8.5 ,  9.  ,  9.5 ,
#           10.  , 10.5 , 11.  , 11.5 , 12.  , 12.5 , 13.  , 13.5 , 14.  ,
#           14.5 , 15.  , 15.5 , 16.  , 16.5 , 17.  , 17.5 , 18.  , 18.5 ,
#           19.  , 19.5 , 20.  , 20.5 , 21.  , 21.5 , 22.  , 22.5 , 23.  ,
#           23.5 , 24.  , 24.5 , 25.  , 25.01, 50.  ]),
#    'prom_name': 'genericWT.ws'}),
#  ('genericWT.pc',
#   {'val': array([0.        , 0.        , 0.        , 0.        , 0.01756943,
#           0.03345113, 0.05457289, 0.08169063, 0.11555623, 0.15691972,
#           0.20653092, 0.26513961, 0.3334952 , 0.41232773, 0.50206334,
#           0.60128904, 0.70383043, 0.79858953, 0.87500428, 0.92877454,
#           0.96229131, 0.98118892, 0.99103377, 0.99586453, 0.9981341 ,
#           0.99916892, 0.99963187, 0.99983688, 0.99992735, 0.99996736,
#           0.99998517, 0.99999317, 0.9999968 , 0.99999848, 0.99999927,
#           0.99999964, 0.99999982, 0.99999991, 0.99999995, 0.99999998,
#           0.99999999, 0.99999999, 1.        , 1.        , 1.        ,
#           1.        , 1.        , 1.        , 1.        , 0.        ,
#           0.        ]),
#    'prom_name': 'genericWT.pc'}),
#  ('genericWT.ct',
#   {'val': array([0.        , 0.        , 0.        , 0.        , 0.79939192,
#           0.79991939, 0.79999442, 0.79999975, 0.79999999, 0.8       ,
#           0.8       , 0.79999999, 0.79999872, 0.79994403, 0.79914431,
#           0.79395901, 0.77593001, 0.73700154, 0.67786244, 0.60739833,
#           0.53560068, 0.46903216, 0.41047387, 0.36027415, 0.31765385,
#           0.2814951 , 0.25070516, 0.22434174, 0.20163193, 0.18195308,
#           0.16480515, 0.14978513, 0.13656606, 0.12488075, 0.11450915,
#           0.10526879, 0.09700733, 0.08959682, 0.08292915, 0.07691253,
#           0.07146859, 0.06653018, 0.06203945, 0.05794642, 0.05420769,
#           0.0507855 , 0.04764682, 0.04476273, 0.04210779, 0.        ,
#           0.        ]),
#    'prom_name': 'genericWT.ct'}),
#  ('genericWake.pcw',
#   {'val': array([  0.        ,   0.        ,   0.        ,   0.        ,
#             3.40084799,   7.20102223,  11.89186601,  17.89779207,
#            25.39045622,  34.5326382 ,  45.49204403,  58.43024402,
#            73.52048863,  90.91896034, 110.75205081, 132.95846634,
#           156.89393403, 181.05707439, 203.24682256, 221.31438593,
#           234.10267291, 241.94833335, 246.20368554, 248.29693428,
#           249.2541612 , 249.67872066, 249.86260615, 249.94113831,
#           249.97461851, 249.98892719, 249.99509999, 249.99779393,
#           249.99898899, 249.99952833, 249.99977588, 249.9998915 ,
#           249.99994649, 249.99997313, 249.99998627, 249.99999286,
#           249.99999623, 249.99999798, 249.99999891, 249.9999994 ,
#           249.99999967, 249.99999983, 249.99999991, 249.99999997,
#           250.        ,   0.        ,   0.        ]),
#    'prom_name': 'genericWake.pcw'}),
#  ('pvp.solar_t',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]), 'prom_name': 'pvp.solar_t'}),
#  ('pvp.Apvp', {'val': array([2.73666644]), 'prom_name': 'pvp.Apvp'}),
#  ('pvp_cost.CAPEX_s',
#   {'val': array([65196874.67579814]), 'prom_name': 'pvp_cost.CAPEX_s'}),
#  ('pvp_cost.OPEX_s',
#   {'val': array([1301410.54778139]), 'prom_name': 'pvp_cost.OPEX_s'}),
#  ('pvp_with_degradation.solar_t_ext_deg',
#   {'val': array([0., 0., 0., ..., 0., 0., 0.]),
#    'prom_name': 'pvp_with_degradation.solar_t_ext_deg'}),
#  ('shared_cost.CAPEX_sh',
#   {'val': array([66664914.99570566]), 'prom_name': 'shared_cost.CAPEX_sh'}),
#  ('shared_cost.OPEX_sh',
#   {'val': array([0.]), 'prom_name': 'shared_cost.OPEX_sh'}),
#  ('wpp.wind_t',
#   {'val': array([216.63691369, 211.60142827, 213.3433593 , ..., 216.51662194,
#           217.35208738, 217.56441215]),
#    'prom_name': 'wpp.wind_t'}),
#  ('wpp_cost.CAPEX_w',
#   {'val': array([2.7558649e+08]), 'prom_name': 'wpp_cost.CAPEX_w'}),
#  ('wpp_cost.OPEX_w',
#   {'val': array([5598766.78143823]), 'prom_name': 'wpp_cost.OPEX_w'}),
#  ('wpp_with_degradation.wind_t_ext_deg',
#   {'val': array([216.63691369, 211.60142827, 213.3433593 , ..., 216.51662194,
#           217.35208738, 217.56441215]),
#    'prom_name': 'wpp_with_degradation.wind_t_ext_deg'})]
